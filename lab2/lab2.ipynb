# %%
#Dispaly a image by openCV

# %%
import numpy as np
import cv2

img=cv2.imread('pic1.jpg',cv2.IMREAD_COLOR)
print("width: {} pixels".format(img.shape[1]))
print("height: {} pixels".format(img.shape[0]))
print("channels: {}".format(img.shape[2]))
# 讓視窗可以自由縮放大小
cv2.namedWindow('image', cv2.WINDOW_NORMAL)

cv2.imshow('image',img) #'image' is the window's name
cv2.waitKey(0)
cv2.imwrite("newimage.jpg", img)
cv2.destroyAllWindows()

# %%
#task 5 Display the loaded image using Matplotlib

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
#開圖片code2
im = Image.open('test.png')
pix=im.load()
print(pix[1,1])    #print pixel's rgb
plt.imshow(im)
# Out:
# (226, 137, 125)

# %%
#Task 6-1:影像處理實作練習(數位影像反白)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import PIL.ImageOps

img = Image.open('test.png')
grayImg = img.convert('L')#轉成灰階圖片
grayImg.save('newimg.png')
invert = PIL.ImageOps.invert(grayImg)
plt.imshow(invert,cmap='gray')#plt.imshow會用預設的調色盤，要加上cmap='gray

# %%
import numpy as np
import cv2
#將圖片反白
img=cv2.imread('test.png',cv2.IMREAD_GRAYSCALE)#sample image將照片讀取成灰階圖
img = cv2.bitwise_not(img)#use not to invert color
# 讓視窗可以自由縮放大小
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img) #'image' is the window's name
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Task 6-2:影像處理實作練習(二值化)

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import PIL.ImageOps
#將圖片轉成二值化影像
img = Image.open('test.png')
grayImg = img.convert('L')#轉成灰階圖片
threshold = np.mean(grayImg)#use mean value as threshold
print(threshold)
table = []
for i in range(256):
    if i < threshold:
      table.append(0)#小於閾值變成黑色
    else:
      table.append(1)#大於閾值變成白色
invertImg = grayImg.point(table, '1')#'1'表示數值只有1、0
grayImg.save('newimg.png')
plt.imshow(invertImg,cmap='gray')#plt.imshow會用預設的調色盤，要加上cmap='gray
# Out:
# 124.04678344726562

# %%
import numpy as np
import cv2
#將圖片轉成二值化影像
img=cv2.imread('test.png',cv2.IMREAD_GRAYSCALE)#將照片讀取成灰階圖
meanValue=img.mean()
print(meanValue)
# 讓視窗可以自由縮放大小
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
ret, convert = cv2.threshold(img,meanValue,255,cv2.THRESH_BINARY)#將灰階圖轉換成二值化 大於mean就變成255(白色)
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',convert) #'image' is the window's name
cv2.waitKey(0)
cv2.imwrite("newimage.jpg", convert)
cv2.destroyAllWindows()
